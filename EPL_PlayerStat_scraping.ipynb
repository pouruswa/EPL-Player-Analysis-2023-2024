# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
import pandas as pd

# %%
driver_path = r"C:\Users\Pourus\Downloads\chromedriver-win64\chromedriver-win64\chromedriver.exe"
driver = webdriver.Chrome(service=Service(driver_path))
url = "https://fbref.com/en/comps/9/2023-2024/stats/2023-2024-Premier-League-Stats"
driver.get(url)
table = driver.find_element(By.ID, "stats_standard")
table_html = table.get_attribute('outerHTML')
driver.quit()
player_stats_df = pd.read_html(table_html)[0]

# %%
print("Current columns:", player_stats_df.columns)
# Out:
# Current columns: MultiIndex([( 'Unnamed: 0_level_0',       'Rk'),
#             ( 'Unnamed: 1_level_0',   'Player'),
#             ( 'Unnamed: 2_level_0',   'Nation'),
#             ( 'Unnamed: 3_level_0',      'Pos'),
#             ( 'Unnamed: 4_level_0',    'Squad'),
#             ( 'Unnamed: 5_level_0',      'Age'),
#             ( 'Unnamed: 6_level_0',     'Born'),
#             (       'Playing Time',       'MP'),
#             (       'Playing Time',   'Starts'),
#             (       'Playing Time',      'Min'),
#             (       'Playing Time',      '90s'),
#             (        'Performance',      'Gls'),
#             (        'Performance',      'Ast'),
#             (        'Performance',      'G+A'),
#             (        'Performance',     'G-PK'),
#             (        'Performance',       'PK'),
#             (        'Performance',    'PKatt'),
#             (        'Performance',     'CrdY'),
#             (        'Performance',     'CrdR'),
# ...

# %%
print("Column index levels:", player_stats_df.columns.nlevels)
print("Column names:", player_stats_df.columns)
# Out:
# Column index levels: 2
# Column names: MultiIndex([( 'Unnamed: 0_level_0',       'Rk'),
#             ( 'Unnamed: 1_level_0',   'Player'),
#             ( 'Unnamed: 2_level_0',   'Nation'),
#             ( 'Unnamed: 3_level_0',      'Pos'),
#             ( 'Unnamed: 4_level_0',    'Squad'),
#             ( 'Unnamed: 5_level_0',      'Age'),
#             ( 'Unnamed: 6_level_0',     'Born'),
#             (       'Playing Time',       'MP'),
#             (       'Playing Time',   'Starts'),
#             (       'Playing Time',      'Min'),
#             (       'Playing Time',      '90s'),
#             (        'Performance',      'Gls'),
#             (        'Performance',      'Ast'),
#             (        'Performance',      'G+A'),
#             (        'Performance',     'G-PK'),
#             (        'Performance',       'PK'),
#             (        'Performance',    'PKatt'),
#             (        'Performance',     'CrdY'),
# ...

# %%
print("Exact column names in the DataFrame:")
for col in player_stats_df.columns:
    print(col)
# Out:
# Exact column names in the DataFrame:
# ('Unnamed: 0_level_0', 'Rk')
# ('Unnamed: 1_level_0', 'Player')
# ('Unnamed: 2_level_0', 'Nation')
# ('Unnamed: 3_level_0', 'Pos')
# ('Unnamed: 4_level_0', 'Squad')
# ('Unnamed: 5_level_0', 'Age')
# ('Unnamed: 6_level_0', 'Born')
# ('Playing Time', 'MP')
# ('Playing Time', 'Starts')
# ('Playing Time', 'Min')
# ('Playing Time', '90s')
# ('Performance', 'Gls')
# ('Performance', 'Ast')
# ('Performance', 'G+A')
# ('Performance', 'G-PK')
# ('Performance', 'PK')
# ('Performance', 'PKatt')
# ('Performance', 'CrdY')
# ('Performance', 'CrdR')
# ('Expected', 'xG')
# ('Expected', 'npxG')
# ('Expected', 'xAG')
# ('Expected', 'npxG+xAG')
# ('Progression', 'PrgC')
# ('Progression', 'PrgP')
# ('Progression', 'PrgR')
# ('Per 90 Minutes', 'Gls')
# ('Per 90 Minutes', 'Ast')
# ('Per 90 Minutes', 'G+A')
# ('Per 90 Minutes', 'G-PK')
# ('Per 90 Minutes', 'G+A-PK')
# ('Per 90 Minutes', 'xG')
# ('Per 90 Minutes', 'xAG')
# ('Per 90 Minutes', 'xG+xAG')
# ...

# %%
desired_columns = [
    ('Unnamed: 1_level_0', 'Player'),
    ('Unnamed: 2_level_0', 'Nation'),
    ('Unnamed: 3_level_0', 'Pos'),
    ('Unnamed: 4_level_0', 'Squad'),
    ('Unnamed: 5_level_0', 'Age'),
    ('Unnamed: 6_level_0', 'Born'),
    ('Playing Time', 'MP'),
    ('Playing Time', 'Starts'),
    ('Playing Time', 'Min'),
    ('Playing Time', '90s'),
    ('Performance', 'Gls'),
    ('Performance', 'Ast'),
    ('Performance', 'G+A'),
    ('Performance', 'G-PK'),
    ('Performance', 'PK'),
    ('Performance', 'PKatt'),
    ('Performance', 'CrdY'),
    ('Performance', 'CrdR'),
    ('Expected', 'xG'),
    ('Expected', 'npxG'),
    ('Expected', 'xAG'),
    ('Expected', 'npxG+xAG'),
    ('Progression', 'PrgC'),
    ('Progression', 'PrgP'),
    ('Progression', 'PrgR'),
    ('Per 90 Minutes', 'Gls'),
    ('Per 90 Minutes', 'Ast'),
    ('Per 90 Minutes', 'G+A'),
    ('Per 90 Minutes', 'G-PK'),
    ('Per 90 Minutes', 'G+A-PK'),
    ('Per 90 Minutes', 'xG'),
    ('Per 90 Minutes', 'xAG'),
    ('Per 90 Minutes', 'xG+xAG'),
    ('Per 90 Minutes', 'npxG'),
    ('Per 90 Minutes', 'npxG+xAG')
]
player_stats_df = player_stats_df[desired_columns]
print("Columns after removing 'Rk' and selecting desired columns:", player_stats_df.columns)
print(player_stats_df.head())
# Out:
# Columns after removing 'Rk' and selecting desired columns: MultiIndex([('Unnamed: 1_level_0',   'Player'),
#             ('Unnamed: 2_level_0',   'Nation'),
#             ('Unnamed: 3_level_0',      'Pos'),
#             ('Unnamed: 4_level_0',    'Squad'),
#             ('Unnamed: 5_level_0',      'Age'),
#             ('Unnamed: 6_level_0',     'Born'),
#             (      'Playing Time',       'MP'),
#             (      'Playing Time',   'Starts'),
#             (      'Playing Time',      'Min'),
#             (      'Playing Time',      '90s'),
#             (       'Performance',      'Gls'),
#             (       'Performance',      'Ast'),
#             (       'Performance',      'G+A'),
#             (       'Performance',     'G-PK'),
#             (       'Performance',       'PK'),
#             (       'Performance',    'PKatt'),
#             (       'Performance',     'CrdY'),
#             (       'Performance',     'CrdR'),
# ...

# %%
player_stats_df
# Out:
#       Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#                   Player             Nation                Pos
# 0             Max Aarons            eng ENG                 DF
# 1      Joshua Acheampong            eng ENG                 DF
# 2            Tyler Adams             us USA                 MF
# 3       Tosin Adarabioyo            eng ENG                 DF
# 4         Elijah Adebayo            eng ENG                 FW
# ..                   ...                ...                ...
# 598       Nicolò Zaniolo             it ITA              FW,MF
# 599        Anass Zaroury             ma MAR              FW,MF
# 600  Oleksandr Zinchenko             ua UKR                 DF
# 601           Kurt Zouma             fr FRA                 DF
# 602      Martin Ødegaard             no NOR                 MF
#
#     Unnamed: 4_level_0 Unnamed: 5_level_0 Unnamed: 6_level_0 Playing Time  \
# ...

# %%
player_stats_df.columns = ['_'.join(col).strip() for col in player_stats_df.columns]
print(player_stats_df.columns)
print(player_stats_df.head())
# Out:
# Index(['Unnamed: 1_level_0_Player', 'Unnamed: 2_level_0_Nation',
#        'Unnamed: 3_level_0_Pos', 'Unnamed: 4_level_0_Squad',
#        'Unnamed: 5_level_0_Age', 'Unnamed: 6_level_0_Born', 'Playing Time_MP',
#        'Playing Time_Starts', 'Playing Time_Min', 'Playing Time_90s',
#        'Performance_Gls', 'Performance_Ast', 'Performance_G+A',
#        'Performance_G-PK', 'Performance_PK', 'Performance_PKatt',
#        'Performance_CrdY', 'Performance_CrdR', 'Expected_xG', 'Expected_npxG',
#        'Expected_xAG', 'Expected_npxG+xAG', 'Progression_PrgC',
#        'Progression_PrgP', 'Progression_PrgR', 'Per 90 Minutes_Gls',
#        'Per 90 Minutes_Ast', 'Per 90 Minutes_G+A', 'Per 90 Minutes_G-PK',
#        'Per 90 Minutes_G+A-PK', 'Per 90 Minutes_xG', 'Per 90 Minutes_xAG',
#        'Per 90 Minutes_xG+xAG', 'Per 90 Minutes_npxG',
#        'Per 90 Minutes_npxG+xAG'],
#       dtype='object')
#   Unnamed: 1_level_0_Player Unnamed: 2_level_0_Nation Unnamed: 3_level_0_Pos  \
# ...

# %%
player_stats_df
# Out:
#     Unnamed: 1_level_0_Player Unnamed: 2_level_0_Nation  \
# 0                  Max Aarons                   eng ENG
# 1           Joshua Acheampong                   eng ENG
# 2                 Tyler Adams                    us USA
# 3            Tosin Adarabioyo                   eng ENG
# 4              Elijah Adebayo                   eng ENG
# ..                        ...                       ...
# 598            Nicolò Zaniolo                    it ITA
# 599             Anass Zaroury                    ma MAR
# 600       Oleksandr Zinchenko                    ua UKR
# 601                Kurt Zouma                    fr FRA
# 602           Martin Ødegaard                    no NOR
#
#     Unnamed: 3_level_0_Pos Unnamed: 4_level_0_Squad Unnamed: 5_level_0_Age  \
# 0                       DF              Bournemouth                     23
# 1                       DF                  Chelsea                     17
# ...

# %%
player_stats_df = player_stats_df.rename(columns={
    'Unnamed: 1_level_0_Player': 'Player',
    'Unnamed: 2_level_0_Nation': 'Nation',
    'Unnamed: 3_level_0_Pos': 'Pos',
    'Unnamed: 4_level_0_Squad': 'Squad',
    'Unnamed: 5_level_0_Age': 'Age',
    'Unnamed: 6_level_0_Born': 'Born',
    'Playing Time_MP':'MP',
    'Playing Time_Starts':'Starts',
    'Playing Time_Mins':'Mins',
    'Playing Time_90s':'90s',
    'Performance_Gls': 'Perf_Gls',
    'Performance_Ast':'Perf_Ast',
    'Performance_G+A':'Perf_G+A',
    'Performance_G-PK':'Perf_G-PK',
    'Performance_PK':'Perf_PK',
    'Performance_PKatt':'Perf_PKatt',
    'Performance_CrdY':'Perf_CrdY',
    'Performance_CrdR':'Perf_CrdR',
    'Expected_xG':'Exp_xG',
    'Expected_npxG':'Exp_npxG',
    'Expected_xAG':'Exp_xAG',
    'Expected_npxG+xAG':'Exp_npxG+xAG',
    'Progression_PrgC':'PrgCarries',
    'Progression_PrgP':'PrgPass',
    'Progression_PrgR':'PrgPass_Rec',
    'Per 90 Minutes_Gls':'90m_Gls',
    'Per 90 Minutes_Ast':'90m_Ast',
    'Per 90 Minutes_G+A':'90m_G+A',
    'Per 90 Minutes_G-PK':'90m_G-PK',
    'Per 90 Minutes_G+A-PK':'90m_G+A-PK',
    'Per 90 Minutes_xG':'90m_xG',
    'Per 90 Minutes_xAG':'90m_xAG',
    'Per 90 Minutes_xG+xAG':'90m_xG+xAG',
    'Per 90 Minutes_npxG':'90m_npxG',
    'Per 90 Minutes_npxG+xAG':'90m_npxG+xAG'
})
print("Renamed columns:", player_stats_df.columns)
print(player_stats_df.head())
# Out:
# Renamed columns: Index(['Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', 'MP', 'Starts',
#        'Playing Time_Min', '90s', 'Perf_Gls', 'Perf_Ast', 'Perf_G+A',
#        'Perf_G-PK', 'Perf_PK', 'Perf_PKatt', 'Perf_CrdY', 'Perf_CrdR',
#        'Exp_xG', 'Exp_npxG', 'Exp_xAG', 'Exp_npxG+xAG', 'PrgCarries',
#        'PrgPass', 'PrgPass_Rec', '90m_Gls', '90m_Ast', '90m_G+A', '90m_G-PK',
#        '90m_G+A-PK', '90m_xG', '90m_xAG', '90m_xG+xAG', '90m_npxG',
#        '90m_npxG+xAG'],
#       dtype='object')
#               Player   Nation Pos        Squad Age  Born  MP Starts  \
# 0         Max Aarons  eng ENG  DF  Bournemouth  23  2000  20     13
# 1  Joshua Acheampong  eng ENG  DF      Chelsea  17  2006   1      0
# 2        Tyler Adams   us USA  MF  Bournemouth  24  1999   3      1
# 3   Tosin Adarabioyo  eng ENG  DF       Fulham  25  1997  20     18
# 4     Elijah Adebayo  eng ENG  FW   Luton Town  25  1998  27     16
#
# ...

# %%
player_stats_df
# Out:
#                   Player   Nation    Pos        Squad Age  Born  MP Starts  \
# 0             Max Aarons  eng ENG     DF  Bournemouth  23  2000  20     13
# 1      Joshua Acheampong  eng ENG     DF      Chelsea  17  2006   1      0
# 2            Tyler Adams   us USA     MF  Bournemouth  24  1999   3      1
# 3       Tosin Adarabioyo  eng ENG     DF       Fulham  25  1997  20     18
# 4         Elijah Adebayo  eng ENG     FW   Luton Town  25  1998  27     16
# ..                   ...      ...    ...          ...  ..   ...  ..    ...
# 598       Nicolò Zaniolo   it ITA  FW,MF  Aston Villa  24  1999  25      9
# 599        Anass Zaroury   ma MAR  FW,MF      Burnley  22  2000   6      1
# 600  Oleksandr Zinchenko   ua UKR     DF      Arsenal  26  1996  27     20
# 601           Kurt Zouma   fr FRA     DF     West Ham  28  1994  33     32
# 602      Martin Ødegaard   no NOR     MF      Arsenal  24  1998  35     35
#
# ...

# %%
unique_nations = player_stats_df['Nation'].value_counts() #fin
print(unique_nations)
# Out:
# eng ENG    200
# br BRA      33
# fr FRA      28
# Nation      23
# es ESP      20
#           ...
# tg TOG       1
# gd GRN       1
# is ISL       1
# gw GNB       1
# nz NZL       1
# Name: Nation, Length: 67, dtype: int64

# %%
player_stats_df['Nation'] = player_stats_df['Nation'].str[-3:]

# %%
player_stats_df
# Out:
#                   Player Nation    Pos        Squad Age  Born  MP Starts  \
# 0             Max Aarons    ENG     DF  Bournemouth  23  2000  20     13
# 1      Joshua Acheampong    ENG     DF      Chelsea  17  2006   1      0
# 2            Tyler Adams    USA     MF  Bournemouth  24  1999   3      1
# 3       Tosin Adarabioyo    ENG     DF       Fulham  25  1997  20     18
# 4         Elijah Adebayo    ENG     FW   Luton Town  25  1998  27     16
# ..                   ...    ...    ...          ...  ..   ...  ..    ...
# 598       Nicolò Zaniolo    ITA  FW,MF  Aston Villa  24  1999  25      9
# 599        Anass Zaroury    MAR  FW,MF      Burnley  22  2000   6      1
# 600  Oleksandr Zinchenko    UKR     DF      Arsenal  26  1996  27     20
# 601           Kurt Zouma    FRA     DF     West Ham  28  1994  33     32
# 602      Martin Ødegaard    NOR     MF      Arsenal  24  1998  35     35
#
#     Playing Time_Min   90s  ... 90m_Gls 90m_Ast 90m_G+A 90m_G-PK 90m_G+A-PK  \
# ...

# %%
player_stats_df.to_csv('EPL_player_stats_23-24.csv', index=False)
